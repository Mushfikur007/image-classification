# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (2.19.0)
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp310-cp310-win_amd64.whl (8.1 MB)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: keras>=3.5.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: packaging in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: setuptools in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.0.1)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.57.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting pillow>=8
#   Using cached pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mushfik\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Installing collected packages: pyparsing, pillow, opencv-python, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 opencv-python-4.11.0.86 pillow-11.2.1 pyparsing-3.2.3
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.2.2
# anyio                        4.9.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# async-lru                    2.0.5
# attrs                        25.3.0
# babel                        2.17.0
# beautifulsoup4               4.13.4
# bleach                       6.2.0
# certifi                      2025.1.31
# cffi                         1.17.1
# charset-normalizer           3.4.1
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.3.2
# cycler                       0.12.1
# debugpy                      1.8.14
# decorator                    5.2.1
# defusedxml                   0.7.1
# exceptiongroup               1.2.2
# executing                    2.2.0
# fastjsonschema               2.21.1
# flatbuffers                  25.2.10
# fonttools                    4.57.0
# fqdn                         1.5.1
# gast                         0.6.0
# google-pasta                 0.2.0
# grpcio                       1.71.0
# h11                          0.14.0
# h5py                         3.13.0
# httpcore                     1.0.8
# httpx                        0.28.1
# idna                         3.10
# ipykernel                    6.29.5
# ipython                      8.35.0
# ipywidgets                   8.1.6
# isoduration                  20.11.0
# jedi                         0.19.2
# Jinja2                       3.1.6
# json5                        0.12.0
# jsonpointer                  3.0.0
# jsonschema                   4.23.0
# jsonschema-specifications    2024.10.1
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# jupyter-events               0.12.0
# jupyter-lsp                  2.2.5
# jupyter_server               2.15.0
# jupyter_server_terminals     0.5.3
# jupyterlab                   4.4.0
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.27.3
# jupyterlab_widgets           3.0.14
# keras                        3.9.2
# kiwisolver                   1.4.8
# libclang                     18.1.1
# Markdown                     3.8
# markdown-it-py               3.0.0
# MarkupSafe                   3.0.2
# matplotlib                   3.10.1
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# mistune                      3.1.3
# ml_dtypes                    0.5.1
# namex                        0.0.8
# nbclient                     0.10.2
# nbconvert                    7.16.6
# nbformat                     5.10.4
# nest-asyncio                 1.6.0
# notebook                     7.4.0
# notebook_shim                0.2.4
# numpy                        2.1.3
# opencv-python                4.11.0.86
# opt_einsum                   3.4.0
# optree                       0.15.0
# overrides                    7.7.0
# packaging                    25.0
# pandocfilters                1.5.1
# parso                        0.8.4
# pillow                       11.2.1
# pip                          22.3.1
# platformdirs                 4.3.7
# prometheus_client            0.21.1
# prompt_toolkit               3.0.51
# protobuf                     5.29.4
# psutil                       7.0.0
# pure_eval                    0.2.3
# pycparser                    2.22
# Pygments                     2.19.1
# pyparsing                    3.2.3
# python-dateutil              2.9.0.post0
# python-json-logger           3.3.0
# python-version               0.0.2
# pywin32                      310
# pywinpty                     2.0.15
# PyYAML                       6.0.2
# pyzmq                        26.4.0
# qtconsole                    5.6.1
# QtPy                         2.4.3
# referencing                  0.36.2
# requests                     2.32.3
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rich                         14.0.0
# rpds-py                      0.24.0
# Send2Trash                   1.8.3
# setuptools                   65.5.0
# six                          1.17.0
# sniffio                      1.3.1
# soupsieve                    2.7
# stack-data                   0.6.3
# tensorboard                  2.19.0
# tensorboard-data-server      0.7.2
# tensorflow                   2.19.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    3.0.1
# terminado                    0.18.1
# tinycss2                     1.4.0
# tomli                        2.2.1
# tornado                      6.4.2
# traitlets                    5.14.3
# types-python-dateutil        2.9.0.20241206
# typing_extensions            4.13.2
# uri-template                 1.3.0
# urllib3                      2.4.0
# wcwidth                      0.2.13
# webcolors                    24.11.1
# webencodings                 0.5.1
# websocket-client             1.8.0
# Werkzeug                     3.1.3
# wheel                        0.45.1
# widgetsnbextension           4.0.14
# wrapt                        1.17.2
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
import cv2
import imghdr

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 305 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])
